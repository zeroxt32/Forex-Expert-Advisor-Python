# %%
#dataset creator for stacked indicators and prices and targets
#Python 3.10 first

# %%
import pandas as pd
import codecs,csv, talib
import matplotlib.pyplot as plt

# %%
forex_data_m1 = pd.read_csv("final_complete_m1short_timestep_4.csv")

# %%
forex_data_m5 = pd.read_csv("final_complete_m5short_timestep_4.csv")

# %%
len(forex_data_m1) == len(forex_data_m5)
# Out:
# True

# %%
forex_data_m1["rsi_12"] = talib.RSI(forex_data_m1["Close"], timeperiod=12)
forex_data_m1["rsi_14"] = talib.RSI(forex_data_m1["Close"], timeperiod=14)
forex_data_m1["mfi"] = talib.MFI(forex_data_m1["High"], forex_data_m1["Low"], forex_data_m1["Close"], forex_data_m1["Volume"], timeperiod=14)
forex_data_m1["adx"] = talib.ADX(forex_data_m1["High"], forex_data_m1["Low"], forex_data_m1["Close"], timeperiod=14)
forex_data_m1["adx_d_plus"] = talib.PLUS_DI(forex_data_m1["High"],forex_data_m1["Low"],forex_data_m1["Close"],timeperiod=14 )
forex_data_m1["adx_d_minus"] = talib.MINUS_DI(forex_data_m1["High"],forex_data_m1["Low"],forex_data_m1["Close"],timeperiod=14 )
forex_data_m1["atr"] = talib.ATR(forex_data_m1["High"],forex_data_m1["Low"],forex_data_m1["Close"],timeperiod=14 )
forex_data_m1["macd_12"] , forex_data_m1["signal"], _= talib.MACD(forex_data_m1["Close"], fastperiod = 12, slowperiod=26, signalperiod = 2)
forex_data_m1["macd_14"] , forex_data_m1["signal"], _= talib.MACD(forex_data_m1["Close"], fastperiod = 14, slowperiod=26, signalperiod = 2)
forex_data_m1["wpr_12"] = talib.WILLR(forex_data_m1["High"], forex_data_m1["Low"], forex_data_m1["Close"], timeperiod=12)
forex_data_m1["wpr_14"] = talib.WILLR(forex_data_m1["High"], forex_data_m1["Low"], forex_data_m1["Close"], timeperiod=14)
forex_data_m1["boll_upper"], forex_data_m1["boll_middle"], forex_data_m1["boll_lower"] = talib.BBANDS(forex_data_m1["Close"], timeperiod = 20, nbdevup = 2, nbdevdn = 2)
forex_data_m1["sto_k_5"], forex_data_m1["sto_d_5"] = talib.STOCH(forex_data_m1["High"], forex_data_m1["Low"], forex_data_m1["Close"], fastk_period = 5, slowk_period = 3, slowd_period=3)
forex_data_m1["sto_k_6"], forex_data_m1["sto_d_6"] = talib.STOCH(forex_data_m1["High"], forex_data_m1["Low"], forex_data_m1["Close"], fastk_period = 6, slowk_period = 3, slowd_period=3)
forex_data_m1["roc"] = talib.ROC(forex_data_m1["Close"], timeperiod=14)
forex_data_m1["cci"] = talib.CCI(forex_data_m1["High"], forex_data_m1["Low"], forex_data_m1["Close"], timeperiod=14)
forex_data_m1["chaikin"] = talib.ADOSC(forex_data_m1["High"], forex_data_m1["Low"], forex_data_m1["Close"], forex_data_m1["Volume"])
forex_data_m1["ad"] = talib.AD(forex_data_m1["High"], forex_data_m1["Low"], forex_data_m1["Close"], forex_data_m1["Volume"])
forex_data_m1["mom"] = talib.MOM(forex_data_m1["Close"], timeperiod=14)

# %%
from sklearn.preprocessing import MinMaxScaler

# Create a DataFrame with indicator data
indicator_df = pd.DataFrame({
    'rsi_12': list(forex_data_m1.iloc[250:3000]['rsi_12'].values),
    'rsi_14': list(forex_data_m1.iloc[250:3000]['rsi_14'].values),
    'mfi': list(forex_data_m1.iloc[250:3000]['mfi'].values),
    'mom': list(forex_data_m1.iloc[250:3000]['mom'].values),
    'atr': list(forex_data_m1.iloc[250:3000]['atr'].values),
    'adx': list(forex_data_m1.iloc[250:3000]['adx'].values),
    'adx_d_plus': list(forex_data_m1.iloc[250:3000]['adx_d_plus'].values), 
    'adx_d_minus':list(forex_data_m1.iloc[250:3000]['adx_d_minus'].values), 
    'atr' : list(forex_data_m1.iloc[250:3000]['atr'].values), 
    'macd_12':list(forex_data_m1.iloc[250:3000]['macd_12'].values),
    'macd_14':list(forex_data_m1.iloc[250:3000]['macd_14'].values),
    'signal':list(forex_data_m1.iloc[250:3000]['signal'].values), 
    'wpr_12': list(forex_data_m1.iloc[250:3000]['wpr_12'].values),
    'wpr_14': list(forex_data_m1.iloc[250:3000]['wpr_14'].values),
    'sto_d_5':list(forex_data_m1.iloc[250:3000]['sto_d_5'].values), 
    'sto_k_5':list(forex_data_m1.iloc[250:3000]['sto_k_5'].values), 
    'sto_d_6':list(forex_data_m1.iloc[250:3000]['sto_d_6'].values), 
    'sto_k_6':list(forex_data_m1.iloc[250:3000]['sto_k_6'].values),     
    'roc':list(forex_data_m1.iloc[250:3000]['roc'].values), 
    'cci':list(forex_data_m1.iloc[250:3000]['cci'].values), 
    'chaikin':list(forex_data_m1.iloc[250:3000]['chaikin'].values), 
    'ad': list(forex_data_m1.iloc[250:3000]['ad'].values),
    'boll_upper':list(forex_data_m1.iloc[250:3000]['boll_upper'].values),
    'boll_middle':list(forex_data_m1.iloc[250:3000]['boll_middle'].values),
    'boll_lower':list(forex_data_m1.iloc[250:3000]['boll_lower'].values),
    'ask':list(forex_data_m1.iloc[250:3000]["Ask"].values)
    
})

# Initialize the MinMaxScaler
scaler = MinMaxScaler()

# Scale the indicator data
scaled_data = scaler.fit_transform(indicator_df)

# Create a new DataFrame with the scaled data
scaled_df = pd.DataFrame(scaled_data, columns=indicator_df.columns)

print(scaled_df)
# Out:
#         rsi_12    rsi_14       mfi       mom       atr       adx  adx_d_plus
# 0     0.472584  0.495093  0.593558  0.563132  0.421086  0.282508    0.376074  \
# 1     0.552602  0.567766  0.585307  0.563354  0.388117  0.268630    0.509701
# 2     0.502175  0.520339  0.529504  0.527041  0.364770  0.258613    0.517675
# 3     0.568481  0.580919  0.606386  0.581566  0.343090  0.249312    0.491263
# 4     0.639102  0.646512  0.597940  0.604775  0.366875  0.255955    0.645340
# ...        ...       ...       ...       ...       ...       ...         ...
# 2745  0.641179  0.639399  0.706231  0.743143  0.617604  0.350361    0.523216
# 2746  0.621982  0.621532  0.736801  0.795447  0.551404  0.346513    0.513670
# 2747  0.491734  0.498709  0.693497  0.627873  0.534244  0.319875    0.483615
# 2748  0.590529  0.593102  0.763060  0.732593  0.518309  0.295140    0.454878
# 2749  0.512640  0.518891  0.679824  0.646419  0.503513  0.272172    0.427449
#
#       adx_d_minus   macd_12   macd_14  ...   sto_d_6   sto_k_6       roc
# 0        0.332640  0.722013  0.725424  ...  0.335859  0.032993  0.559707  \
# 1        0.317552  0.705988  0.710963  ...  0.160890  0.123810  0.559922
# 2        0.300010  0.681135  0.688358  ...  0.108917  0.169947  0.524072
# 3        0.282940  0.674584  0.681681  ...  0.189489  0.274709  0.577906
# 4        0.252345  0.685119  0.690234  ...  0.275203  0.380952  0.600809
# ...           ...       ...       ...  ...       ...       ...       ...
# 2745     0.218112  0.689067  0.659774  ...  0.932766  0.829983  0.736258
# 2746     0.213472  0.690823  0.665406  ...  0.825610  0.678532  0.787753
# 2747     0.367939  0.663349  0.644456  ...  0.655732  0.458682  0.623150
# 2748     0.344136  0.663892  0.647518  ...  0.521682  0.427834  0.725938
# 2749     0.321416  0.644949  0.632868  ...  0.409873  0.343104  0.641346
#
#            cci   chaikin        ad  boll_upper  boll_middle  boll_lower
# 0     0.361376  0.581634  0.413496    0.589908     0.588433    0.579695  \
# 1     0.415550  0.569479  0.418050    0.586352     0.591058    0.588332
# 2     0.397122  0.553609  0.416022    0.585065     0.592057    0.591553
# 3     0.416471  0.585957  0.426004    0.584684     0.593272    0.594308
# 4     0.486088  0.635946  0.436200    0.586028     0.594876    0.596121
# ...        ...       ...       ...         ...          ...         ...
# 2745  0.634825  0.937104  0.800087    0.814991     0.794196    0.760538
# 2746  0.615580  0.904870  0.800694    0.819008     0.796828    0.761731
# 2747  0.535748  0.834037  0.794623    0.819261     0.798893    0.765522
# 2748  0.557521  0.794280  0.798605    0.821470     0.801955    0.769336
# 2749  0.513858  0.719094  0.789716    0.821196     0.804270    0.774135
#
#            ask
# 0     0.562561
# 1     0.577763
# 2     0.567472
# 3     0.580435
# 4     0.595891
# ...        ...
# 2745  0.803380
# 2746  0.799986
# 2747  0.774095
# 2748  0.795400
# 2749  0.778067
#
# [2750 rows x 25 columns]

# %%
scaled_df.to_csv("scaled_df.csv", index=False)

# %%
#Create the y labels

# %%
close = list(forex_data_m1.iloc[250:3000]["Open"])
boll_upper = list(indicator_df.iloc[:]["boll_upper"])
boll_middle = list(indicator_df.iloc[:]["boll_middle"])
boll_lower = list(indicator_df.iloc[:]["boll_lower"])
print(len(close))
plt.figure(figsize=(6, 4))
plt.plot(close, label="close")
plt.plot(boll_upper, label="boll_upper")
plt.plot(boll_middle, label="boll_middle")
plt.plot(boll_lower, label="boll_lower")
plt.legend(loc="upper right")
plt.title("After training")
plt.show()
# Out:
# 2750

# %%
close = list(forex_data_m5.iloc[250:3000]["Close"])
print(len(close))
plt.figure(figsize=(6, 4))
plt.plot(close, label="close")
plt.legend(loc="upper right")
plt.title("After training")
plt.show()
# Out:
# 2750

# %%
from tabulate import tabulate
headers = ["index", "Ask", "Bid", "Boll_upper", "Boll_middle", "Boll_lower", "status"]
counter = 0
y = []
for i , row in forex_data_m1[250:3000].iterrows():
    r = []
    # print(i, row["Ask"], indicator_df.iloc[counter]["boll_lower"])
    if row["Ask"] > indicator_df.iloc[counter]['boll_middle']:
        status = 0
        y.append(0)
    elif row["Ask"] < indicator_df.iloc[counter]["boll_middle"]:
        status = 1
        y.append(1)
    else:
        status = 1
        y.append(1)
    # r.append([i,row["Ask"], row["Bid"], indicator_df.iloc[counter]["boll_upper"], indicator_df.iloc[counter]["boll_middle"],indicator_df.iloc[counter]["boll_lower"] , status])
    # print(tabulate(r, headers=headers, tablefmt ="grid"))

    counter+=1
    # if counter > 2000:
    #     break

# %%
len(y)
# Out:
# 2750

# %%
scaled_y = pd.DataFrame({
    "y": y
})
scaled_y.to_csv("stacked_y.csv", index=False)

# %%
scaled_y.head(5)
# Out:
#    y
# 0  1
# 1  0
# 2  1
# 3  0
# 4  0

# %%
#from here use python 3.11


import pandas as pd
import numpy as np

# Example indicator data

scaled_df = pd.read_csv("scaled_df.csv")
# Stacking the indicator values
stacked_feature = []
num_indicators = len(scaled_df.columns)
window_size = 10

for i in range(window_size, len(scaled_df)):
    stacked_values = []
    for j in range(num_indicators):
        indicator_values = scaled_df.iloc[i - window_size:i, j].values
        stacked_values.extend(indicator_values)
    stacked_feature.append(stacked_values)

# Convert stacked_feature to a NumPy array
stacked_feature = np.array(stacked_feature)

print(stacked_feature.shape)
# Out:
# (2740, 250)

# %%
stacked_feature[0].shape
# Out:
# (250,)

# %%
stacked_feature = np.expand_dims(stacked_feature, axis = 0)
stacked_feature.shape
# Out:
# (1, 2740, 250)

# %%
stacked_y = pd.read_csv("stacked_y.csv")

# %%
len(list(stacked_y.iloc[:2740]["y"]))
# Out:
# 2740

# %%
y = np.array( list(stacked_y.iloc[:2740]["y"]))
y = y.reshape(1,len(y), 1)
y.shape
# Out:
# (1, 2740, 1)

# %%
import numpy as np
import os
from tensorflow import keras
from ncps import wirings
from ncps.tf import LTC
import pandas as pd
import matplotlib.pyplot as plt

# %%
wiring = wirings.AutoNCP(8,1) # 8 neurons in total, 1 output (motor neuron)

model = keras.models.Sequential(
    [
        keras.layers.InputLayer(input_shape=(None, 250)),
        # here we could potentially add layers before and after the LTC network
        LTC(wiring, return_sequences=True),
    ]
)
model.compile(
    optimizer=keras.optimizers.Adam(0.01), loss='mean_squared_error'
)

model.summary()
hist = model.fit(x=stacked_feature, y=y, batch_size=32, epochs=1000,verbose=1)

# %%
prediction = model(stacked_feature).numpy()
plt.figure(figsize=(6, 4))
plt.plot(y[0, :, 0], label="Target output")
plt.plot(prediction[0, :, 0], label="LTC output",linestyle="dashed")
plt.ylim((-1, 1))
plt.legend(loc="upper right")
plt.title("After training")
plt.show()

# %%
forex_data_m1 = pd.read_csv("final_complete_m1short_timestep_4.csv")

# %%
_position = 0

stacked_feature.shape
# Out:
# (1, 2740, 250)

# %%
counter = 250
_position = -1
current_trade = {}
total_profit = 0
def trade(entry_price, current_price, _position):
    current_trade = {}
    current_trade["entry_price"] = entry_price
    current_trade["current_price"] = current_price
    current_trade["_position"] = _position
    current_trade["profit"] = 0
    return current_trade
for i in range(0, 2740):
    ask = forex_data_m1.iloc[counter]["Ask"]
    bid = forex_data_m1.iloc[counter]["Bid"]
    _x = stacked_feature[0][i]
    _x = _x.reshape(1,1,len(_x))
    pred = model.predict(_x,verbose=0)[0][0][0]
    # print(i, pred)
    if _position == -1:
        if pred < 1:#open buy
            _position = 0
            current_trade = trade(float(forex_data_m1.iloc[counter]["Ask"]), float(forex_data_m1.iloc[counter]["Bid"]),_position)
            print("Buy Opened")
        else:#open sell
            _position = 1
            current_trade = trade(float(forex_data_m1.iloc[counter]["Bid"]), float(forex_data_m1.iloc[counter]["Ask"]),_position)
            print("Sell Opened")
    elif _position == 0 and pred < 1:#buy position continues
        current_trade["current_price"] = float(forex_data_m1.iloc[counter]["Bid"])
        profit = current_trade["current_price"] - current_trade["entry_price"]
        # print(f"Buy Continues Profit {profit}")
        
    elif _position == 1 and pred >= 1:#sell position continues
        profit = current_trade["entry_price"] - current_trade["current_price"]
        current_trade["current_price"] = float(forex_data_m1.iloc[counter]["Ask"])
        # print(f"Sell Continues Profit {profit}")
    elif _position == 0 and pred >= 1:#close buy position calculate profit and open sell position
        profit = current_trade["current_price"] - current_trade["entry_price"]
        _position = -1
        total_profit+=profit
        print(f"Buy Closed probs {pred} Total Profits {total_profit}")
        
    elif _position == 1 and pred < 1: # close sell position calculate profit and close sell pos
        _position = -1
        
        total_profit += profit
        print(f"Sell Closed probs {pred}Total Profits {total_profit}")


    
    counter += 1
    # break
# Out:
# Buy Opened
# Buy Closed probs 1.0025936365127563 Total Profits -0.3500000000003638
# Buy Opened
# Buy Closed probs 1.0033799409866333 Total Profits 34.779999999999745
# Sell Opened
# Sell Closed probs 0.996333658695221Total Profits 52.38000000000011
# Sell Opened
# Sell Closed probs 0.998256266117096Total Profits 50.710000000000036
# Buy Opened
# Buy Closed probs 1.001905918121338 Total Profits 44.090000000000146
# Sell Opened
# Sell Closed probs 0.9999993443489075Total Profits 45.150000000000546
# Sell Opened
# Sell Closed probs 0.9991434216499329Total Profits 45.45000000000073
# Buy Opened
# Buy Closed probs 1.001927375793457 Total Profits 87.66000000000076
# Sell Opened
# Sell Closed probs 0.9935395121574402Total Profits 98.58000000000084
# Buy Opened
# Buy Closed probs 1.0003622770309448 Total Profits 96.91000000000076
# Sell Opened
# Sell Closed probs 0.9980722069740295Total Profits 95.24000000000069
# Buy Opened
# Buy Closed probs 1.0021417140960693 Total Profits 100.5
# Sell Opened
# Sell Closed probs 0.9996621012687683Total Profits 111.52999999999975
# Sell Opened
# Sell Closed probs 0.9982395172119141Total Profits 115.76999999999953
# Buy Opened
# Buy Closed probs 1.0013158321380615 Total Profits 114.04999999999927
# Buy Opened
# Buy Closed probs 1.00042724609375 Total Profits 112.3799999999992
# Buy Opened
# Buy Closed probs 1.0006736516952515 Total Profits 111.38999999999942
# Buy Opened
# Buy Closed probs 1.0032050609588623 Total Profits 113.51999999999953
# Buy Opened
# Buy Closed probs 1.0018599033355713 Total Profits 127.99999999999909
# Sell Opened
# Sell Closed probs 0.8601723909378052Total Profits 130.41999999999916
# Buy Opened
# Buy Closed probs 1.0010415315628052 Total Profits 124.27999999999975
# Buy Opened
# Buy Closed probs 1.002168893814087 Total Profits 122.61000000000058
# Sell Opened
# Sell Closed probs 0.5755371451377869Total Profits 120.94000000000142
# Buy Opened
# Buy Closed probs 1.001817226409912 Total Profits 115.58000000000084
# Buy Opened
# Buy Closed probs 1.0054223537445068 Total Profits 132.8700000000008
# Buy Opened
# Buy Closed probs 1.0005143880844116 Total Profits 139.15000000000055
# Buy Opened
# Buy Closed probs 1.0010839700698853 Total Profits 166.28999999999996
# Buy Opened
# Buy Closed probs 1.0018402338027954 Total Profits 166.35000000000036
# Buy Opened
# Buy Closed probs 1.0008903741836548 Total Profits 161.89000000000033
# Sell Opened
# Sell Closed probs 0.9978048801422119Total Profits 162.89000000000033
# Buy Opened
# Buy Closed probs 1.0009284019470215 Total Profits 158.76999999999953
# Buy Opened
# Buy Closed probs 1.002632737159729 Total Profits 161.6899999999996
# Buy Opened
# Buy Closed probs 1.0000789165496826 Total Profits 164.72000000000025
# Buy Opened
# Buy Closed probs 1.0016740560531616 Total Profits 163.05000000000018
# Sell Opened
# Sell Closed probs 0.9943488240242004Total Profits 161.3800000000001
# Buy Opened
# Buy Closed probs 1.0025736093521118 Total Profits 157.1199999999999
# Sell Opened
# Sell Closed probs 0.9971615076065063Total Profits 157.6199999999999
# Buy Opened
# Buy Closed probs 1.000084400177002 Total Profits 169.98999999999978
# Sell Opened
# Sell Closed probs 0.9932016730308533Total Profits 182.35999999999967
# Buy Opened
# Buy Closed probs 1.0003021955490112 Total Profits 177.2599999999993
# Buy Opened
# Buy Closed probs 1.0042446851730347 Total Profits 172.78999999999905
# Sell Opened
# Sell Closed probs 0.9999918937683105Total Profits 200.1999999999989
# Sell Opened
# Sell Closed probs 0.9978993535041809Total Profits 204.73999999999887
# Buy Opened
# Buy Closed probs 1.0009266138076782 Total Profits 206.59999999999854
# Buy Opened
# Buy Closed probs 1.0019155740737915 Total Profits 224.73999999999796
# Sell Opened
# Sell Closed probs 0.9928610920906067Total Profits 236.1399999999976
# Buy Opened
# Buy Closed probs 1.0038782358169556 Total Profits 235.72999999999774
# Sell Opened
# Sell Closed probs 0.9997064471244812Total Profits 234.05999999999767
# Buy Opened
# Buy Closed probs 1.0020287036895752 Total Profits 296.34999999999764
# Buy Opened
# Buy Closed probs 1.0001380443572998 Total Profits 303.0099999999975
# Sell Opened
# Sell Closed probs 0.998813271522522Total Profits 309.66999999999734
# Buy Opened
# Buy Closed probs 1.0008479356765747 Total Profits 309.1899999999978
# Sell Opened
# Sell Closed probs 0.9980673789978027Total Profits 305.5099999999975
# Buy Opened
# Buy Closed probs 1.0004392862319946 Total Profits 305.29999999999745
# Sell Opened
# Sell Closed probs 0.9993341565132141Total Profits 305.42999999999756
# Buy Opened
# Buy Closed probs 1.003804087638855 Total Profits 303.7599999999975
# Buy Opened
# Buy Closed probs 1.002587914466858 Total Profits 323.319999999997
# Sell Opened
# Sell Closed probs 0.9560691714286804Total Profits 340.6499999999969
# Buy Opened
# Buy Closed probs 1.0052305459976196 Total Profits 369.4499999999971
# Buy Opened
# Buy Closed probs 1.0012454986572266 Total Profits 360.5899999999974
# Buy Opened
# Buy Closed probs 1.0021873712539673 Total Profits 351.7199999999975
# Sell Opened
# Sell Closed probs 0.9984655380249023Total Profits 352.3799999999974
# Buy Opened
# Buy Closed probs 1.0025569200515747 Total Profits 363.4699999999975
# Buy Opened
# Buy Closed probs 1.0011563301086426 Total Profits 399.04999999999745
# Buy Opened
# Buy Closed probs 1.001668095588684 Total Profits 402.47999999999683
# Sell Opened
# Sell Closed probs 0.9959567189216614Total Profits 405.9099999999962
# Sell Opened
# Sell Closed probs 0.9972643852233887Total Profits 413.36999999999625
# Buy Opened
# Buy Closed probs 1.001224160194397 Total Profits 409.4699999999966
# Buy Opened
# Buy Closed probs 1.0007308721542358 Total Profits 404.4099999999962
# Buy Opened
# Buy Closed probs 1.002526879310608 Total Profits 404.23999999999614
# Buy Opened
# Buy Closed probs 1.000309705734253 Total Profits 375.149999999996
# Sell Opened
# Sell Closed probs 0.9974785447120667Total Profits 346.05999999999585
# Buy Opened
# Buy Closed probs 1.0007104873657227 Total Profits 345.0999999999958
# Buy Opened
# Buy Closed probs 1.0038357973098755 Total Profits 344.04999999999563
# Sell Opened
# Sell Closed probs 0.99848473072052Total Profits 342.37999999999556
# Sell Opened
# Sell Closed probs 0.9831469655036926Total Profits 340.7099999999955
# Buy Opened
# Buy Closed probs 1.0010614395141602 Total Profits 337.479999999995
# Sell Opened
# Sell Closed probs 0.964686930179596Total Profits 334.24999999999454
# Buy Opened
# Buy Closed probs 1.0032910108566284 Total Profits 329.4099999999944
# Buy Opened
# Buy Closed probs 1.0006846189498901 Total Profits 331.9199999999946
# Sell Opened
# Sell Closed probs 0.9978174567222595Total Profits 337.7199999999948
# Sell Opened
# Sell Closed probs 0.9965260624885559Total Profits 343.519999999995
# Buy Opened
# Buy Closed probs 1.000907301902771 Total Profits 339.7099999999955
# Buy Opened
# Buy Closed probs 1.0002086162567139 Total Profits 341.74999999999545
# Buy Opened
# Buy Closed probs 1.0017729997634888 Total Profits 338.2699999999959
# Sell Opened
# Sell Closed probs 0.9918685555458069Total Profits 344.80999999999585
# Buy Opened
# Buy Closed probs 1.0008748769760132 Total Profits 363.37999999999556
# Buy Opened
# Buy Closed probs 1.0051661729812622 Total Profits 410.7099999999955
# Sell Opened
# Sell Closed probs 0.9772132039070129Total Profits 419.79999999999563
# Buy Opened
# Buy Closed probs 1.00019109249115 Total Profits 418.12999999999556
# Buy Opened
# Buy Closed probs 1.0008288621902466 Total Profits 427.6599999999953
# Sell Opened
# Sell Closed probs 0.9953163266181946Total Profits 425.98999999999523
# Buy Opened
# Buy Closed probs 1.0043569803237915 Total Profits 427.8399999999947
# Sell Opened
# Sell Closed probs 0.9995104670524597Total Profits 440.7999999999947
# Sell Opened
# Sell Closed probs 0.9962893724441528Total Profits 453.75999999999476
# Buy Opened
# Buy Closed probs 1.000340223312378 Total Profits 459.2199999999948
# Buy Opened
# Buy Closed probs 1.0011630058288574 Total Profits 462.88999999999487
# Buy Opened
# Buy Closed probs 1.0003347396850586 Total Profits 502.57999999999447
# Buy Opened
# Buy Closed probs 1.0027889013290405 Total Profits 506.24999999999454
# Buy Opened
# Buy Closed probs 1.0018738508224487 Total Profits 504.57999999999447
# Sell Opened
# Sell Closed probs 0.9982303380966187Total Profits 500.7799999999943
# Sell Opened
# Sell Closed probs 0.9942803382873535Total Profits 496.9799999999941
# Buy Opened
# Buy Closed probs 1.0017483234405518 Total Profits 495.30999999999403
# Buy Opened
# Buy Closed probs 1.0002610683441162 Total Profits 495.2099999999946
# Buy Opened
# Buy Closed probs 1.0052528381347656 Total Profits 489.76999999999407
# Buy Opened
# Buy Closed probs 1.000792145729065 Total Profits 494.20999999999367
# Sell Opened
# Sell Closed probs 0.9956750869750977Total Profits 492.5399999999936
# Buy Opened
# Buy Closed probs 1.0015921592712402 Total Profits 501.0599999999931
# Sell Opened
# Sell Closed probs 0.9976129531860352Total Profits 502.0899999999938
# Buy Opened
# Buy Closed probs 1.0009241104125977 Total Profits 567.4699999999939
# Sell Opened
# Sell Closed probs 0.9832183718681335Total Profits 608.4599999999937
# Buy Opened
# Buy Closed probs 1.0045504570007324 Total Profits 646.2899999999936
# Sell Opened
# Sell Closed probs 0.9980207681655884Total Profits 659.6199999999935
# Buy Opened
# Buy Closed probs 1.003198266029358 Total Profits 664.4599999999937
# Sell Opened
# Sell Closed probs 0.9984527826309204Total Profits 667.0399999999936
# Buy Opened
# Buy Closed probs 1.0024046897888184 Total Profits 673.5399999999936
# Buy Opened
# Buy Closed probs 1.0010536909103394 Total Profits 681.1499999999933
# Buy Opened
# Buy Closed probs 1.0011764764785767 Total Profits 679.7099999999937
# Sell Opened
# Sell Closed probs 0.9999412298202515Total Profits 678.2699999999941
# Sell Opened
# Sell Closed probs 0.9954184293746948Total Profits 683.8799999999937
# Buy Opened
# Buy Closed probs 1.0028244256973267 Total Profits 682.2099999999937
# Buy Opened
# Buy Closed probs 1.0047552585601807 Total Profits 710.7599999999929
# Sell Opened
# Sell Closed probs 0.9957398176193237Total Profits 709.469999999993
# Buy Opened
# Buy Closed probs 1.0029040575027466 Total Profits 754.139999999993
# Sell Opened
# Sell Closed probs 0.9932882785797119Total Profits 755.639999999993
# Buy Opened
# Buy Closed probs 1.0043667554855347 Total Profits 761.3799999999937
# Sell Opened
# Sell Closed probs 0.9967867732048035Total Profits 759.7099999999937
# Buy Opened
# Buy Closed probs 1.000231385231018 Total Profits 793.0099999999929
# Buy Opened
# Buy Closed probs 1.0018861293792725 Total Profits 878.6099999999933
# Sell Opened
# Sell Closed probs 0.9977582693099976Total Profits 881.4999999999927
# Buy Opened
# Buy Closed probs 1.0009849071502686 Total Profits 879.8299999999927
# Buy Opened
# Buy Closed probs 1.003069281578064 Total Profits 880.3099999999922
# Buy Opened
# Buy Closed probs 1.0017274618148804 Total Profits 917.1099999999924
# Sell Opened
# Sell Closed probs 0.9947957396507263Total Profits 943.3999999999924
# Buy Opened
# Buy Closed probs 1.004463791847229 Total Profits 941.089999999992
# Buy Opened
# Buy Closed probs 1.0022203922271729 Total Profits 946.1299999999919
# Buy Opened
# Buy Closed probs 1.002368450164795 Total Profits 968.6499999999915
# Buy Opened
# Buy Closed probs 1.0004724264144897 Total Profits 971.6099999999915
# Buy Opened
# Buy Closed probs 1.0009093284606934 Total Profits 974.9699999999912
# Buy Opened
# Buy Closed probs 1.0002466440200806 Total Profits 1017.4899999999907
# Sell Opened
# Sell Closed probs 0.9992339015007019Total Profits 1015.8199999999906
# Sell Opened
# Sell Closed probs 0.9995566010475159Total Profits 1014.1499999999905
# Buy Opened
# Buy Closed probs 1.0034565925598145 Total Profits 1007.5399999999909
# Buy Opened
# Buy Closed probs 1.0038784742355347 Total Profits 1012.8299999999908
# Buy Opened
# Buy Closed probs 1.0016471147537231 Total Profits 1018.0299999999916
# Buy Opened
# Buy Closed probs 1.0004931688308716 Total Profits 1013.3099999999922
# Buy Opened
# Buy Closed probs 1.0020031929016113 Total Profits 1012.339999999992
# Sell Opened
# Sell Closed probs 0.9978065490722656Total Profits 1017.0599999999913
# Buy Opened

# %%
forex_data_m1.iloc[250][:]
# Out:
# TimeStamp                                        2023.04.11-05:22:02
# image_path         Volatility_100_Index_M1_1158233112023.04.11-05...
# Open                                                         7271.84
# Close                                                        7272.66
# High                                                         7272.66
# Low                                                          7271.84
# Ask                                                          7274.33
# Bid                                                          7272.66
# MA 5                                                         7274.21
# MA 8                                                       7269.4275
# MA 10                                                       7270.593
# MA 14                                                      7282.5514
# MA 18                                                      7292.2994
# MA 24                                                      7306.9633
# MA 30                                                      7315.3433
# MA 50                                                      7321.3682
# MA 100                                                      7336.132
# MA 200                                                     7411.0888
# Stochastic %K                                                 61.082
# Stochastic %D                                                74.0123
# RSI                                                          34.1185
# MACD                                                        -17.5959
# MACD Signal                                                  -17.912
# Volume                                                             2
# Spread                                                         167.0
# Account Balance                                              10151.8
# Profit                                                           0.0
# Take Profit                                                  20.1111
# Stop Loss                                                    20.1111
# Trailing Stop                                                20.1111
# Lot Size                                                         0.2
# unknown                                                            5
# Name: 250, dtype: object

# %%
forex_data_m1.iloc[3000][:]
# Out:
# TimeStamp                                        2023.04.11-11:32:38
# image_path         Volatility_100_Index_M1_1158233112023.04.11-11...
# Open                                                         7338.54
# Close                                                        7337.01
# High                                                         7339.45
# Low                                                          7330.46
# Ask                                                          7338.68
# Bid                                                          7337.01
# MA 5                                                        7331.158
# MA 8                                                       7336.6987
# MA 10                                                       7339.107
# MA 14                                                      7345.2679
# MA 18                                                      7348.3294
# MA 24                                                      7352.2787
# MA 30                                                        7353.77
# MA 50                                                       7359.744
# MA 100                                                      7337.095
# MA 200                                                     7268.0077
# Stochastic %K                                                51.9076
# Stochastic %D                                                34.0792
# RSI                                                          43.4847
# MACD                                                         -7.2786
# MACD Signal                                                  -5.1234
# Volume                                                            20
# Spread                                                         167.0
# Account Balance                                              10151.8
# Profit                                                           0.0
# Take Profit                                                  20.1111
# Stop Loss                                                    20.1111
# Trailing Stop                                                20.1111
# Lot Size                                                         0.2
# unknown                                                            5
# Name: 3000, dtype: object

# %%
model.save("gemini/models/gemini.h5")

# %%
wiring = wirings.AutoNCP(8,1) # 8 neurons in total, 1 output (motor neuron)

gemini = keras.models.Sequential(
    [
        keras.layers.InputLayer(input_shape=(None, 250)),
        # here we could potentially add layers before and after the LTC network
        LTC(wiring, return_sequences=True),
    ]
)
gemini.compile(
    optimizer=keras.optimizers.Adam(0.01), loss='mean_squared_error'
)

gemini.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  ltc_1 (LTC)                 (None, None, 1)           8782
#
# =================================================================
# Total params: 8,782
# Trainable params: 8,782
# Non-trainable params: 0
# _________________________________________________________________

# %%
gemini.load_weights('gemini/models/gemini.h5')

# %%
counter = 250
_position = -1
current_trade = {}
total_profit = 0
def trade(entry_price, current_price, _position):
    current_trade = {}
    current_trade["entry_price"] = entry_price
    current_trade["current_price"] = current_price
    current_trade["_position"] = _position
    current_trade["profit"] = 0
    return current_trade
for i in range(0, 2740):
    ask = forex_data_m1.iloc[counter]["Ask"]
    bid = forex_data_m1.iloc[counter]["Bid"]
    _x = stacked_feature[0][i]
    _x = _x.reshape(1,1,len(_x))
    pred = gemini.predict(_x,verbose=0)[0][0][0]
    # print(i, pred)
    if _position == -1:
        if pred < 1:#open buy
            _position = 0
            current_trade = trade(float(forex_data_m1.iloc[counter]["Ask"]), float(forex_data_m1.iloc[counter]["Bid"]),_position)
            print("Buy Opened")
        else:#open sell
            _position = 1
            current_trade = trade(float(forex_data_m1.iloc[counter]["Bid"]), float(forex_data_m1.iloc[counter]["Ask"]),_position)
            print("Sell Opened")
    elif _position == 0 and pred < 1:#buy position continues
        current_trade["current_price"] = float(forex_data_m1.iloc[counter]["Bid"])
        profit = current_trade["current_price"] - current_trade["entry_price"]
        # print(f"Buy Continues Profit {profit}")
        
    elif _position == 1 and pred >= 1:#sell position continues
        profit = current_trade["entry_price"] - current_trade["current_price"]
        current_trade["current_price"] = float(forex_data_m1.iloc[counter]["Ask"])
        # print(f"Sell Continues Profit {profit}")
    elif _position == 0 and pred >= 1:#close buy position calculate profit and open sell position
        profit = current_trade["current_price"] - current_trade["entry_price"]
        _position = -1
        total_profit+=profit
        print(f"Buy Closed probs {pred} Total Profits {total_profit}")
        
    elif _position == 1 and pred < 1: # close sell position calculate profit and close sell pos
        _position = -1
        
        total_profit += profit
        print(f"Sell Closed probs {pred}Total Profits {total_profit}")


    
    counter += 1
    # break

# %%
#Gemini Testing Lab
