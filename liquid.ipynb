# %%
import numpy as np

# %%
import ray

# %%
ray.init()
# Out:
# 2023-05-19 09:42:14,408	INFO worker.py:1616 -- Started a local Ray instance. View the dashboard at http://127.0.0.1:8265
# RayContext(dashboard_url='127.0.0.1:8265', python_version='3.11.2', ray_version='2.4.0', ray_commit='4479f66d4db967d3c9dd0af2572061276ba926ba', address_info={'node_ip_address': '127.0.1.1', 'raylet_ip_address': '127.0.1.1', 'redis_address': None, 'object_store_address': '/tmp/ray/session_2023-05-19_09-42-04_391992_1289582/sockets/plasma_store', 'raylet_socket_name': '/tmp/ray/session_2023-05-19_09-42-04_391992_1289582/sockets/raylet', 'webui_url': '127.0.0.1:8265', 'session_dir': '/tmp/ray/session_2023-05-19_09-42-04_391992_1289582', 'metrics_export_port': 62058, 'gcs_address': '127.0.1.1:64669', 'address': '127.0.1.1:64669', 'dashboard_agent_listen_port': 52365, 'node_id': 'a75995a41190a49cc1f73f0ea4f1fb5fa8491c4ec4a2bf8a7cde5261'})

# %%
from ray.rllib.models.modelv2 import ModelV2
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 from ray.rllib.models.modelv2 import ModelV2
#
# File ~/Projects/ForexLab/dataset/episode2/env/lib/python3.11/site-packages/ray/rllib/__init__.py:7
#       3 from ray._private.usage import usage_lib
#       5 # Note: do not introduce unnecessary library dependencies here, e.g. gym.
#       6 # This file is imported from the tune module in order to register RLlib agents.
# ----> 7 from ray.rllib.env.base_env import BaseEnv
#       8 from ray.rllib.env.external_env import ExternalEnv
#       9 from ray.rllib.env.multi_agent_env import MultiAgentEnv
#
# File ~/Projects/ForexLab/dataset/episode2/env/lib/python3.11/site-packages/ray/rllib/env/__init__.py:6
#       4 from ray.rllib.env.external_multi_agent_env import ExternalMultiAgentEnv
#       5 from ray.rllib.env.multi_agent_env import MultiAgentEnv
# ----> 6 from ray.rllib.env.policy_client import PolicyClient
#       7 from ray.rllib.env.policy_server_input import PolicyServerInput
#       8 from ray.rllib.env.remote_base_env import RemoteBaseEnv
#
# File ~/Projects/ForexLab/dataset/episode2/env/lib/python3.11/site-packages/ray/rllib/env/policy_client.py:17
#      15 from ray.rllib.env.external_multi_agent_env import ExternalMultiAgentEnv
#      16 from ray.rllib.env.multi_agent_env import MultiAgentEnv
# ---> 17 from ray.rllib.policy.sample_batch import MultiAgentBatch
#      18 from ray.rllib.utils.annotations import PublicAPI
#      19 from ray.rllib.utils.typing import (
#      20     MultiAgentDict,
#      21     EnvInfoDict,
#      22     EnvObsType,
#      23     EnvActionType,
#      24 )
#
# File ~/Projects/ForexLab/dataset/episode2/env/lib/python3.11/site-packages/ray/rllib/policy/__init__.py:1
# ----> 1 from ray.rllib.policy.policy import Policy
#       2 from ray.rllib.policy.torch_policy import TorchPolicy
#       3 from ray.rllib.policy.tf_policy import TFPolicy
#
# File ~/Projects/ForexLab/dataset/episode2/env/lib/python3.11/site-packages/ray/rllib/policy/policy.py:29
#      27 from ray.air.checkpoint import Checkpoint
#      28 import ray.cloudpickle as pickle
# ---> 29 from ray.rllib.models.action_dist import ActionDistribution
#      30 from ray.rllib.models.catalog import ModelCatalog
#      31 from ray.rllib.models.modelv2 import ModelV2
#
# File ~/Projects/ForexLab/dataset/episode2/env/lib/python3.11/site-packages/ray/rllib/models/__init__.py:1
# ----> 1 from ray.rllib.models.action_dist import ActionDistribution
#       2 from ray.rllib.models.catalog import ModelCatalog, MODEL_DEFAULTS
#       3 from ray.rllib.models.modelv2 import ModelV2
#
# File ~/Projects/ForexLab/dataset/episode2/env/lib/python3.11/site-packages/ray/rllib/models/action_dist.py:4
#       1 import numpy as np
#       2 import gymnasium as gym
# ----> 4 from ray.rllib.models.modelv2 import ModelV2
#       5 from ray.rllib.utils.annotations import DeveloperAPI
#       6 from ray.rllib.utils.typing import TensorType, List, Union, ModelConfigDict
#
# File ~/Projects/ForexLab/dataset/episode2/env/lib/python3.11/site-packages/ray/rllib/models/modelv2.py:8
#       5 import numpy as np
#       6 from typing import Dict, List, Any, Union
# ----> 8 from ray.rllib.models.preprocessors import get_preprocessor, RepeatedValuesPreprocessor
#       9 from ray.rllib.models.repeated_values import RepeatedValues
#      10 from ray.rllib.policy.sample_batch import SampleBatch
#
# File ~/Projects/ForexLab/dataset/episode2/env/lib/python3.11/site-packages/ray/rllib/models/preprocessors.py:10
#       8 from ray.rllib.utils.spaces.repeated import Repeated
#       9 from ray.rllib.utils.typing import TensorType
# ---> 10 from ray.rllib.utils.images import resize
#      11 from ray.rllib.utils.spaces.space_utils import convert_element_to_space_type
#      13 ATARI_OBS_SHAPE = (210, 160, 3)
#
# File ~/Projects/ForexLab/dataset/episode2/env/lib/python3.11/site-packages/ray/rllib/utils/__init__.py:29
#      21 from ray.rllib.utils.pre_checks.env import check_env
#      22 from ray.rllib.utils.schedules import (
#      23     LinearSchedule,
#      24     PiecewiseSchedule,
#    (...)
#      27     ConstantSchedule,
#      28 )
# ---> 29 from ray.rllib.utils.test_utils import (
#      30     check,
#      31     check_compute_single_action,
#      32     check_train_results,
#      33     framework_iterator,
#      34 )
#      35 from ray.tune.utils import merge_dicts, deep_update
#      38 @DeveloperAPI
#      39 def add_mixins(base, mixins, reversed=False):
#
# File ~/Projects/ForexLab/dataset/episode2/env/lib/python3.11/site-packages/ray/rllib/utils/test_utils.py:27
#      24 import yaml
#      26 import ray
# ---> 27 from ray import air, tune
#      28 from ray.rllib.utils.framework import try_import_jax, try_import_tf, try_import_torch
#      29 from ray.rllib.env.wrappers.atari_wrappers import is_atari, wrap_deepmind
#
# File ~/Projects/ForexLab/dataset/episode2/env/lib/python3.11/site-packages/ray/air/__init__.py:2
#       1 from ray.air.checkpoint import Checkpoint
# ----> 2 from ray.air.config import (
#       3     DatasetConfig,
#       4     RunConfig,
#       5     ScalingConfig,
#       6     FailureConfig,
#       7     CheckpointConfig,
#       8 )
#       9 from ray.air.data_batch_type import DataBatchType
#      10 from ray.air.result import Result
#
# File ~/Projects/ForexLab/dataset/episode2/env/lib/python3.11/site-packages/ray/air/config.py:18
#      16 from ray.util.annotations import PublicAPI
#      17 from ray.widgets import Template, make_table_html_repr
# ---> 18 from ray.data.preprocessor import Preprocessor
#      20 if TYPE_CHECKING:
#      21     from ray.data import Dataset
#
# File ~/Projects/ForexLab/dataset/episode2/env/lib/python3.11/site-packages/ray/data/__init__.py:9
#       6 if sys.version_info >= (3, 7):
#       7     import pandas  # noqa
# ----> 9 from ray.data._internal.compute import ActorPoolStrategy
#      10 from ray.data._internal.progress_bar import set_progress_bars
#      11 from ray.data._internal.execution.interfaces import ExecutionOptions, ExecutionResources
#
# File ~/Projects/ForexLab/dataset/episode2/env/lib/python3.11/site-packages/ray/data/_internal/compute.py:9
#       7 from ray.data._internal.block_list import BlockList
#       8 from ray.data._internal.delegating_block_builder import DelegatingBlockBuilder
# ----> 9 from ray.data._internal.execution.interfaces import TaskContext
#      10 from ray.data._internal.progress_bar import ProgressBar
#      11 from ray.data._internal.remote_fn import cached_remote_fn
#
# File ~/Projects/ForexLab/dataset/episode2/env/lib/python3.11/site-packages/ray/data/_internal/execution/interfaces.py:187
#     177         """Return copy with all set values scaled by `f`."""
#     178         return ExecutionResources(
#     179             cpu=self.cpu * f if self.cpu is not None else None,
#     180             gpu=self.gpu * f if self.gpu is not None else None,
#    (...)
#     183             else None,
#     184         )
# --> 187 @dataclass
#     188 class ExecutionOptions:
#     189     """Common options for execution.
#     190
#     191     Some options may not be supported on all executors (e.g., resource limits).
#    (...)
#     207             option is useful for performance debugging. Off by default.
#     208     """
#     210     # Set a soft limit on the resource usage during execution. This is not supported
#     211     # in bulk execution mode.
#
# File /usr/lib/python3.11/dataclasses.py:1220, in dataclass(cls, init, repr, eq, order, unsafe_hash, frozen, match_args, kw_only, slots, weakref_slot)
#    1217     return wrap
#    1219 # We're called as @dataclass without parens.
# -> 1220 return wrap(cls)
#
# File /usr/lib/python3.11/dataclasses.py:1210, in dataclass.<locals>.wrap(cls)
#    1209 def wrap(cls):
# -> 1210     return _process_class(cls, init, repr, eq, order, unsafe_hash,
#    1211                           frozen, match_args, kw_only, slots,
#    1212                           weakref_slot)
#
# File /usr/lib/python3.11/dataclasses.py:958, in _process_class(cls, init, repr, eq, order, unsafe_hash, frozen, match_args, kw_only, slots, weakref_slot)
#     955         kw_only = True
#     956     else:
#     957         # Otherwise it's a field of some type.
# --> 958         cls_fields.append(_get_field(cls, name, type, kw_only))
#     960 for f in cls_fields:
#     961     fields[f.name] = f
#
# File /usr/lib/python3.11/dataclasses.py:815, in _get_field(cls, a_name, a_type, default_kw_only)
#     811 # For real fields, disallow mutable defaults.  Use unhashable as a proxy
#     812 # indicator for mutability.  Read the __hash__ attribute from the class,
#     813 # not the instance.
#     814 if f._field_type is _FIELD and f.default.__class__.__hash__ is None:
# --> 815     raise ValueError(f'mutable default {type(f.default)} for field '
#     816                      f'{f.name} is not allowed: use default_factory')
#     818 return f
#
# ValueError: mutable default <class 'ray.data._internal.execution.interfaces.ExecutionResources'> for field resource_limits is not allowed: use default_factory
# *** SIGTERM received at time=1684486482 on cpu 0 ***
# PC: @     0x7fde627aecb6  (unknown)  epoll_wait
#     @     0x7fde626e1f90  (unknown)  (unknown)
# [2023-05-19 11:54:42,686 E 1289582 1289582] logging.cc:361: *** SIGTERM received at time=1684486482 on cpu 0 ***
# [2023-05-19 11:54:42,686 E 1289582 1289582] logging.cc:361: PC: @     0x7fde627aecb6  (unknown)  epoll_wait
# [2023-05-19 11:54:42,686 E 1289582 1289582] logging.cc:361:     @     0x7fde626e1f90  (unknown)  (unknown)

# %%
from ray.rllib.models.tf.recurrent_net import RecurrentNetwork
